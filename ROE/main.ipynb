# %%
import time

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
url = 'https://movielens.org/explore/genres/crime'

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get(url)

time.sleep(25)

data = driver.page_source
# Out:
# [WDM] - Downloading: 100%|██████████| 6.30M/6.30M [00:06<00:00, 1.06MB/s]

# %%
data
# Out:
# '<html class="no-js" xmlns="http://www.w3.org/1999/html"><!--<![endif]--><head>\n    <base href="/">\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <title>Explore</title>\n    <meta name="description" content="">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n    <!-- do not cache this page, please, to make upgrades easier -->\n    <meta http-equiv="Cache-control" content="no-store, must-revalidate">\n\n    <!-- favicon. thanks to realfavicongenerator.net -->\n    <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png">\n    <link rel="apple-touch-icon" sizes="60x60" href="/apple-touch-icon-60x60.png">\n    <link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png">\n    <link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32">\n    <link rel="icon" type="image/png" href="/favicon-96x96.png" sizes="96x96">\n    <link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16">\n    <link rel="manifest" href="/manifest.json">\n    <meta name="msapplication-TileColor" content="#2b5797">\n    <meta name="theme-color" content="#ffffff">\n\n    <link href="https://fonts.googleapis.com/css?family=Raleway|Roboto" rel="stylesheet">\n    <link type="text/plain" rel="author" href="/humans.txt">\n\n    <!-- Global site tag (gtag.js) - Google Analytics -->\n    <script type="application/javascript" async="" defer="" src="https://by2.uservoice.com/t2/203198/web/track.js?_=1689791757233&amp;s=0&amp;c=__uvSessionData0&amp;d=eyJlIjp7InUiOiJodHRwczovL21vdmllbGVucy5vcmcvZXhwbG9yZS9nZW5yZXMvY3JpbWUiLCJyIjoiIn19"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-TY2XJRE9PE&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-42433938-3"></script>\n    <script>\n      window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n      gtag(\'config\', \'UA-42433938-3\', { \'send_page_view\': false });\n    </script>\n\n  <link href="/app.a8106f22ebb031667800.css" rel="stylesheet"><style type="text/css" media="screen">.uv-icon{box-sizing:border-box;display:inline-block;cursor:pointer;position:relative;transition:all 300ms;width:39px;height:39px;position:fixed;z-index:100002;opacity:0.8;transition:opacity 100ms}.uv-icon.uv-bottom-right{bottom:10px;right:12px}.uv-icon.uv-top-right{top:10px;right:12px}.uv-icon.uv-bottom-left{bottom:10px;left:12px}.uv-icon.uv-top-left{top:10px;left:12px}.uv-icon.uv-is-selected{opacity:1}.uv-icon svg{width:39px;height:39px}.uv-icon .uv-tooltip-container{position:relative}.uv-icon .uv-tooltip-container .uv-icon-tooltip{display:none;position:absolute;height:20px;padding:4px 8px;background-color:#464653;color:white;font-size:12px;border-radius:4px;line-height:18px;font-family:"Open Sans", sans-serif;white-space:nowrap}.uv-icon .uv-tooltip-container .uv-icon-tooltip.left,.uv-icon .uv-tooltip-container .uv-icon-tooltip.right{top:0;bottom:0;margin:auto 10px}.uv-icon .uv-tooltip-container .uv-icon-tooltip.top,.uv-icon .uv-tooltip-container .uv-icon-tooltip.bottom{transform:translate(-30%);margin:10px auto}.uv-icon .uv-tooltip-container .uv-icon-tooltip.top{bottom:100%}.uv-icon .uv-tooltip-container .uv-icon-tooltip.bottom{top:100%}.uv-icon .uv-tooltip-container .uv-icon-tooltip.left{right:100%}.uv-icon .uv-tooltip-container .uv-icon-tooltip.right{left:100%}.uv-icon .uv-tooltip-container:hover .uv-icon-tooltip{display:block}.uv-icon-trigger{display:block;width: ...

# %%
soup = BeautifulSoup(data, 'html.parser')

element = soup.find('div', class_='movie-search-results-container')

for i in element:
    print(i.text.split("new ")[-1].replace("List",""))
# Out:
# The Shawshank Redemption4.41994DramaCrime4.4/5predicted4.4/5 123153 ratings
# The Godfather4.31972DramaCrime4.3/5predicted4.3/5 75625 ratings
# The Godfather Part II4.31974DramaCrime4.3/5predicted4.3/5 47651 ratings
# The Usual Suspects4.31995DramaCrimeThriller4.3/5predicted4.3/5 73413 ratings
# Pulp Fiction4.21994ThrillerCrime4.2/5predicted4.2/5 109485 ratings
# The Dark Knight4.22008DramaActionCrimeThriller4.2/5predicted4.2/5 66164 ratings
# GoodFellas4.21990DramaCrime4.2/5predicted4.2/5 45003 ratings
# City of God4.22002DramaCrime4.2/5predicted4.2/5 27528 ratings
# The Silence of the Lambs4.11991CrimeDramaThriller4.1/5predicted4.1/5 102471 ratings
# Twin Peaks4.31990CrimeDramaMysteryTV Movie4.3/5predicted4.3/5 1165 ratings
# The Departed4.12006DramaThrillerCrime4.1/5predicted4.1/5 36990 ratings
# Chinatown4.11974CrimeDramaMysteryThriller4.1/5predicted4.1/5 22239 ratings
# Fargo4.11996CrimeDramaThriller4.1/5predicted4.1/5 62439 ratings
# Double Indemnity4.21944CrimeThrillerRomance4.2/5predicted4.2/5 6875 ratings
# The Sting4.11973ComedyCrimeDrama4.1/5predicted4.1/5 19645 ratings
# To Kill a Mockingbird4.11962DramaCrime4.1/5predicted4.1/5 19894 ratings
# M4.11931DramaActionThrillerCrime4.1/5predicted4.2/5 6010 ratings
# Léon: The Professional4.11994CrimeDramaAction4.1/5predicted4.1/5 43928 ratings
# High and Low4.21963CrimeDramaMysteryThriller4.2/5predicted4.2/5 1308 ratings
# Reservoir Dogs4.11992CrimeThriller4.1/5predicted4.1/5 45801 ratings
# Se7en4.11995CrimeMysteryThriller4.1/5predicted4.1/5 66229 ratings
# The Maltese Falcon4.11941MysteryCrimeThriller4.1/5predicted4.1/5 15714 ratings
# The Big Sleep4.11946CrimeMysteryRomanceThriller4.1/5predicted4.1/5 7093 ratings
# Taxi Driver4.11976CrimeDrama4.1/5predicted4.1/5 39449 ratings
